# %% [markdown]
# <a href="https://colab.research.google.com/github/Gladiator07/Natural-Language-Processing/blob/main/LSTM/text_generator_charachter_level_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text Generator with Character Level LSTM

# %% [markdown]
# Text generation using a character LSTM, specifically we want to
# generate new names as inspiration for those having a baby :)
# Although this is for name generation, the code is general in the
# way that you can just send in any large text file (shakespear text, etc)
# and it will generate it.

# %%
import torch
import torch.nn as nn
import string
import random
import sys
from torch.utils.tensorboard import SummaryWriter

# %%
# getting data
# !pip install Unidecode
# !wget https://raw.githubusercontent.com/aladdinpersson/Machine-Learning-Collection/master/ML/Projects/text_generation_babynames/data/names.txt
# Out:
# Collecting Unidecode
#   Downloading https://files.pythonhosted.org/packages/9e/25/723487ca2a52ebcee88a34d7d1f5a4b80b793f179ee0f62d5371938dfa01/Unidecode-1.2.0-py2.py3-none-any.whl (241kB)
#      |████████████████████████████████| 245kB 9.0MB/s
# Installing collected packages: Unidecode
# Successfully installed Unidecode-1.2.0
# --2021-04-18 16:42:30--  https://raw.githubusercontent.com/aladdinpersson/Machine-Learning-Collection/master/ML/Projects/text_generation_babynames/data/names.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7303572 (7.0M) [text/plain]
# Saving to: ‘names.txt’
#
# names.txt           100%[===================>]   6.96M  45.0MB/s    in 0.2s
#
# 2021-04-18 16:42:31 (45.0 MB/s) - ‘names.txt’ saved [7303572/7303572]

# %%
import unidecode
file = unidecode.unidecode(open("names.txt").read())

# %%
# device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# get charachters from string.printable
all_characters = string.printable
n_characters = len(all_characters)
print(all_characters)
# Out:
# 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        self.embed = nn.Embedding(input_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self,x,hidden,cell):
        out = self.embed(x)
        out, (hidden,cell) = self.lstm(out.unsqueeze(1), (hidden, cell))
        out = self.fc(out.reshape(out.shape[0], -1))
        return out, (hidden, cell)
    
    def init_hidden(self, batch_size):
        hidden = torch.zeros(self.num_layers, batch_size, self.hidden_size).to(device)
        cell = torch.zeros(self.num_layers, batch_size, self.hidden_size).to(device)
        return hidden, cell

# %%
class Generator():
    def __init__(self):
        self.chunk_len = 250
        self.num_epochs = 5000
        self.batch_size = 1
        self.print_every = 50
        self.hidden_size = 256
        self.num_layers = 2
        self.lr = 0.003
    
    def char_tensor(self, string):
        tensor = torch.zeros(len(string)).long()
        for c in range(len(string)):
            tensor[c] = all_characters.index(string[c])
        return tensor
    
    def get_random_batch(self):
        start_idx = random.randint(0, len(file) - self.chunk_len)
        end_idx = start_idx + self.chunk_len + 1
        text_str = file[start_idx:end_idx]
        text_input = torch.zeros(self.batch_size, self.chunk_len)
        text_target = torch.zeros(self.batch_size, self.chunk_len)

        for i in range(self.batch_size):
            text_input[i,:] = self.char_tensor(text_str[:-1])
            text_target[i,:] = self.char_tensor(text_str[1:])
        
        return text_input.long(), text_target.long()

    def generate(self, initial_str='A', predict_len=100, temperature=0.85):
        hidden, cell = self.rnn.init_hidden(batch_size=self.batch_size)
        initial_input = self.char_tensor(initial_str)
        predicted = initial_str

        last_char = initial_input[-1]

        for p in range(predict_len):
            output, (hidden, cell) = self.rnn(
                last_char.view(1).to(device), hidden, cell
            )
            output_dist = output.data.view(-1).div(temperature).exp()
            top_char = torch.multinomial(output_dist, 1)[0]
            predicted_char = all_characters[top_char]
            predicted += predicted_char
            last_char = self.char_tensor(predicted_char)

        return predicted
    
    def train(self):
        self.rnn = RNN(n_characters, self.hidden_size, self.num_layers, n_characters).to(device)

        optimizer = torch.optim.Adam(self.rnn.parameters(), lr=self.lr)
        criterion = nn.CrossEntropyLoss()
        writer = SummaryWriter(f'runs/names0')
        print("=> Starting training")

        for epoch in range(1, self.num_epochs + 1):
            inp, target = self.get_random_batch()
            hidden, cell = self.rnn.init_hidden(batch_size=self.batch_size)
            self.rnn.zero_grad()
            loss = 0
            inp = inp.to(device)
            target = target.to(device)

            for c in range(self.chunk_len):
                output, (hidden,cell) = self.rnn(inp[:, c], hidden, cell)
                loss += criterion(output, target[:, c])
            
            loss.backward()
            optimizer.step()
            loss = loss.item() / self.chunk_len

            if epoch % self.print_every == 0:
                print(f'Loss: {loss}')
                print(self.generate())

            writer.add_scalar('Training loss', loss, global_step=epoch)

# %%
gennames = Generator()
gennames.train()
# Out:
# => Starting training
# Loss: 2.351725830078125
# A
# Nadie
# Tiari
# Malosa
# Barnwab
# Kasierl
# Binna
# Janhe
# Marrlta
# Jnelcucia
# Cargiet
# Riasse
# Arihan
# 6silag
# r
# Rri
# Loss: 2.298428466796875
# Amine
# Jesy
# Jannen
# Jalerisn
# Barlin
# Phutbel
# Maria
# TKiery
# Ria
# Shetint
# Lened
# Ericw
# Janna
# Koxonn
# Cani
# Donn
# Loss: 2.26296533203125
# An
# Kelley
# Panelre
# Chinna
# Har
# Tarie
# Hanalio
# Neiesta
# Alficie
# Cryle
# Alereph
# Asher
# Hana
# Marina
# Lintia
# Sha
# Loss: 1.875780517578125
# And
# Daytha
# Wonta
# Ctarlino
# Mathanda
# Carista
# Alshela
# Jarredra
# Carlie
# Parla
# Anamina
# Dellina
# Tamin
# Alymie
# Loss: 2.501237548828125
# Ane
# Rwerotth
# cuutho
# Allynna
# Duyda
# Vennie
# Vondy
# Maith
# Mellice
# Calyn
# Sustee
# Frinna
# Via
# AmeR
# Arvelet
# Der
# Loss: 2.13074755859375
# Aka
# Leora
# Richas
# Loniqa
# Chlpy
# Noust
# Anmia
# Serby
# Jackre
# Junton
# Letha
# Rametta
# Hari
# Mynald
# Onda
# Nora
# Mat
# Loss: 2.122806884765625
# Adina
# Torandra
# Josania
# Kanie
# Elia
# Ka
# Carana
# Rizaleen
# Todred
# Jacquel
# Meleen
# Jace
# Irieone
# Paudaria
# Keul
# Loss: 1.793730224609375
# Arla
# Aldobe
# Trevella
# Alysan
# Josele
# Kayla
# Vally
# Kathelle
# Rickella
# Nicia
# Rayah
# Thelley
# Arnee
# Allye
# Lana
# Loss: 2.0308680419921874
# Ario
# Larleen
# Oila
# Cherrie
# Belie
# Merlip
# Phemeria
# Lora
# Gerina
# Loanne
# Krardie
# Antha
# Jeanne
# Styne
# Delishe
# Loss: 1.8785926513671876
# Amons
# Samiana
# Suney
# Chardy
# Gyeth
# Marthor
# Juliola
# Maxina
# Kengeloy
# Rowa
# Savan
# Elan
# Helleigh
# Leyla
# Lauri
# Loss: 2.254683349609375
# Aya
# Stefry
# Eviel
# Ronal
# Stede
# Heral
# Willa
# Carte
# Rosis
# Julielyn
# Brayce
# Rena
# Anna
# Scyl
# Ralen
# Ley
# Jonny
# C
# Loss: 2.0052786865234373
# Alima
# Vinna
# Bemar
# Kellad
# Lenna
# Roxeller
# Prusti
# Aldrena
# Darrin
# Guell
# Jack
# Danie
# Tran
# Rodnica
# Jayman
# Al
# Loss: 1.69554150390625
# Arce
# Lene
# Timew
# Sterence
# Grosella
# Bentean
# Welly
# Angelleen
# Alexsana
# Sona
# Hoper
# Micelle
# Alfredolyn
# Jerl
# Loss: 1.7401300048828126
# Amine
# Daya
# Alexina
# Janie
# Betharie
# Maris
# Woselina
# Alissa
# Brendo
# Mestene
# Jamie
# Nara
# Rhanda
# Lessie
# Isha
#
# Loss: 1.804029296875
# Adger
# Cara
# Doyn
# Carlina
# Preston
# Leres
# Brando
# Edmiri
# Kristi
# Clian
# Brexen
# Tanyah
# Amaro
# Malton
# Anthen
# Mo
# Loss: 1.841149658203125
# Allia
# Geordon
# Eltonia
# Eiden
# Wandy
# Conda
# Norice
# Rathen
# Cori
# Rosel
# Ayonn
# Jandie
# Bette
# Amon
# Andra
# Adigor
# Loss: 1.4791231689453126
# Aronne
# Troy
# Nicherle
# Tiera
# Cerisha
# Ernest
# Arri
# Josha
# Damilly
# Sarus
# Shanice
# Leoro
# Larold
# Iusaine
# Shanl
# Loss: 1.42306103515625
# Anne
# Edtia
# Bribette
# Juliana
# Sabay
# Leona
# Katryn
# Richard
# Lousley
# Leobert
# Pailah
# Lawrence
# Terrace
# Nahal
#
# Loss: 1.565329833984375
# Arna
# Ariana
# Waley
# Haley
# Jazmyn
# Lauren
# Natalinda
# Wandi
# Brann
# Anali
# Katherine
# Daron
# Fredsher
# Doish
# Guro
# Loss: 1.5267818603515626
# Avaiannd
# Hora
# Malla
# Alvin
# Kaire
# Bradlind
# Cadelia
# Anton
# Sadaya
# Matoria
# Marjora
# Tiana
# novano
# Lerene
# Kay
# Loss: 1.7483466796875
# Aggust
# Dugtor
# Estuni
# Alison
# Holeine
# Gayler
# Fissa
# Mamriel
# Harla
# Marthie
# Antor
# Carl
# DileCold
# Eriton
# Eri
# Loss: 1.586950439453125
# Archah
# Tami
# Shana
# Nathan
# Petry
# Nathan
# Anica
# Gloria
# Ewie
# Deylid
# Elwis
# Delisha
# Dylon
# Duana
# Brian
# Biana
#
# Loss: 1.837122802734375
# Alesque
# Georgie
# Janisetta
# Kandy
# Kali
# Hann
# Gordon
# Sandra
# Garen
# Darry
# Blana
# Mori
# Sherry
# Jonette
# Jeffrey
# Loss: 1.45577099609375
# Arra
# Lucitte
# Penny
# Lailda
# Laken
# Robert
# Alina
# Bernidi
# Danne
# Alan
# Alex
# Angelina
# Abbie
# Amada
# Audre
# Benny
# Loss: 1.4743385009765626
# Allita
# Ella
# Dora
# Even
# Kaitlynn
# Kristy
# Rovanne
# Shaana
# Angelinda
# Devyn
# Davira
# Donnetter
# Doy
# Dona
# Dona
# A
# Loss: 1.603581787109375
# AGarence
# Scallo
# Agna
# Maxila
# Freda
# Faura
# Laura
# Leigh
# Marchell
# Katharine
# Olivia
# Fronda
# Felicia
# Frances
#
# Loss: 1.3342550048828126
# Abbi
# Serah
# Teresa
# Tamara
# Savan
# Steven
# Camily
# Gailene
# Fabi
# Jacob
# Lina
# Mactie
# Daleen
# Dalory
# Lisa
# Killia
# Loss: 1.95441015625
# Armon
# Alma
# Ammary
# Albert
# Christina
# Clyler
# Christina
# Geraldo
# Cadysha
# Alyssandra
# Collie
# Clip
# Cilbert
# Co
# Loss: 1.2386962890625
# Abn
# Rene
# Richar
# Torise
# Tiana
# Stephenie
# Tarriela
# Wyndon
# Willa
# Carline
# Carley
# Ciana
# Bonnie
# Ezabeth
# Harl
# Loss: 1.464635498046875
# Alicia
# Jada
# Jackie
# Jeffery
# Esther
# Glyssa
# Borin
# Princes
# Brana
# Geas
# Georgia
# Camit
# Crystal
# Cristy
# Cha
# Ed
# Loss: 1.579604248046875
# Arice
# Yuanie
# Jimi
# Tiley
# Theodore
# Jackselaia
# Jese
# Kristina
# Willia
# Philip
# Reena
# Angela
# Conjil
# Charlo
# Cl
# Loss: 1.682359619140625
# Anas
# Beotric
# Steve
# Charlius
# Elson
# Gabry
# Guadalupe
# Leigh
# Margo
# Marian
# Ariana
# Betty
# Carlen
# Carles
# Alex
#
# Loss: 1.325727294921875
# Adorie
# Alejam
# Addiam
# Andas
# Andrew
# Andrew
# Aula
# Angelica
# Adelly
# Bryann
# Dashelyn
# Darrien
# Ernest
# Finden
# M
# Loss: 1.203304443359375
# Amilia
# Alyn
# May
# Noual
# Rachel
# Rose
# Theomar
# Shirly
# Sheila
# Shanna
# Arthur
# Edwin
# Kristine
# Natalie
# Maziel
# M
# Loss: 1.4547410888671874
# Adria
# Allyson
# Audro
# Carlton
# Copy
# Darnae
# Danneth
# Kelle
# Isabel
# Kylan
# Kent
# Kalen
# Kaitlynn
# Kenneth
# Jolina
# Loss: 1.40679296875
# Aylen
# Develin
# Deanna
# Hollie
# Gene
# Fabima
# Francesca
# Gwin
# Ramona
# Susan
# Stephania
# Beigus
# Emman
# Codie
# Feli
# Loss: 1.4240223388671875
# Armary
# Ricard
# Rosale
# Sherry
# Shelly
# Sherrie
# Terenca
# Shankie
# Shanty
# Sharla
# Terred
# Rogerio
# Rosannette
# St
# Loss: 1.2488497314453124
# Antiano
# Corrie
# Denessa
# Brandonne
# Cleyton
# Edward
# Quin
# Pearl
# Pennaure
# Wandall
# Jimmy
# Joyce
# Jackie
# Celsee
# Loss: 1.142800537109375
# Anstelinda
# Alissa
# Ann
# Madeline
# Bernady
# Cannah
# Darlena
# Dannie
# Devin
# Eben
# Kristina
# Imen
# Angela
# Daniela
#
# Loss: 1.4397369384765626
# Adrielle
# Amasha
# Alexandra
# Caryne
# Charlie
# Brad
# Theresca
# Coli
# Conia
# Carlie
# Brian
# Bill
# Darrice
# Damie
# Del
# Loss: 1.1464112548828125
# Anara
# Clara
# Derik
# Dartha
# Deila
# Kenneth
# Kaylon
# Mariael
# Mirgil
# Margueth
# Maryam
# Marlo
# Quinky
# Sally
# Rosel
# Loss: 1.1691273193359375
# Andra
# Anidan
# Bonika
# Elouston
# Chassie
# Chanter
# Ginny
# Rosemary
# Conna
# Lous
# Randaca
# Joelle
# Rayana
# Violet
# V
# Loss: 1.5209195556640625
# Antley
# Amandra
# Betty
# Babit
# Earl
# Gabry
# Martha
# Ana
# Andrea
# Amiz
# Assa
# Anne
# Ala
# Amain
# Bethany
# Bradley
# Curn
# Loss: 1.534392578125
# Abelle
# Eddie
# Emily
# Gregory
# Gui
# Heide
# Florence
# Eveor
# Sandy
# Brie
# Corrin
# Diarrot
# Edrian
# Darrell
# Dereddy
#
# Loss: 1.49039697265625
# Anya
# Bethanie
# James
# Justicia
# Vincent
# Elizabeth
# Darina
# Delonda
# Emily
# Isaac
# Kristina
# Pamela
# Rachael
# Rod
# Loss: 1.16644921875
# Anton
# Zayne
# Tomi
# Tristina
# Sagan
# Tyrahia
# Tarah
# Tony
# Brett
# Cherish
# Carrie
# Arnithnie
# Cherise
# Evan
# Lavina
# Loss: 1.4839420166015624
# Annette
# Gloria
# Maddishune
# Malaura
# Mily
# Mars
# Nealy
# Nichald
# Norma
# Royce
# Talcia
# Tammmarie
# Valine
# Alicio
#
# Loss: 1.344827880859375
# Abby
# Erik
# Iva
# Jodi
# Jerna
# Julia
# Jocelyn
# Jerry
# Janie
# Jody
# Joselyn
# Johnnya
# Johanna
# Verna
# Imani
# Jamie
# Joa
# Loss: 1.2699940185546874
# ABraelina
# Adelina
# Charino
# Jessie
# Margaret
# Marjo
# Markisha
# Marie
# Mayce
# Micheal
# Ruben
# Brace
# Emerore
# Chri
# Loss: 1.3095731201171874
# Allisa
# Andrea
# Andrea
# Adalyn
# Adam
# Averyn
# Braiden
# Broddyn
# Bora
# Efrain
# Lancey
# Tamara
# Tonia
# Autumn
# Bonda
#
# Loss: 1.4064044189453124
# Anna
# Skyler
# Craig
# Gayle
# Janice
# Junice
# Karyn
# Karissa
# Kathyry
# Lance
# Lance
# Marion
# Augustina
# Christian
# Da
# Loss: 1.26406298828125
# Anara
# Royce
# Alberta
# Mitchell
# Torri
# Bernard
# Bryce
# Breelle
# Carolyn
# Adolph
# Alox
# Anita
# Berny
# Derrick
# Desh
# Loss: 2.13823583984375
# Ala
# Ardelina
# Marita
# Melody
# Marianne
# Pearl
# Russell
# Nicholas
# Ruby
# Stephen
# Shanna
# Shaun
# Valeria
# Davyn
# Ha
# Loss: 1.6371610107421875
# A
# Anny
# Dan
# Desharia
# Dorian
# Donn
# Deric
# Destina
# Destinice
# Daisy
# Danyelle
# Emmett
# Corine
# Carolyn
# Charlie
#
# Loss: 1.2535408935546875
# Adria
# Beth
# Barry
# Cassie
# Sandyce
# Cathiel
# Carson
# Carolin
# Draver
# Damiana
# Daleb
# Dornon
# Deann
# Deshary
# Dala
# Loss: 1.1661783447265626
# Adithya
# Shayla
# Chustine
# Cecelia
# Deannette
# Kaitlin
# Liz
# Madeline
# Marian
# Peter
# Alfred
# Becky
# Caroline
# Daw
# Loss: 1.4656466064453124
# Andrew
# Beatrice
# Cori
# Caitlin
# Bonja
# Gabin
# Gailly
# Lucille
# Morgan
# Margaret
# Mary
# Mony
# Mandy
# Miranda
# Ronni
# Loss: 1.12568603515625
# Anton
# Trinis
# William
# Westce
# Jeremiah
# Urina
# Ayden
# Aya
# Saller
# Reba
# Roberto
# Alea
# Alphon
# Emma
# Dole
# Courtn
# Loss: 1.0340550537109374
# Anta
# Alexandra
# Barbara
# Betty
# Tammy
# Miki
# Atyn
# Brayden
# Carolyn
# Celeste
# Brenda
# Chastina
# Cecilia
# Christin
# Loss: 1.109796875
# Abi
# Arie
# Brittany
# Banette
# Carla
# Christie
# Conny
# Christy
# Kennika
# Kim
# Mablo
# Sally
# Chris
# Clarice
# Lilly
# La
# Loss: 1.33264453125
# Antonia
# Adrian
# Adam
# Daniel
# Dewando
# Deborah
# Dezira
# Dalija
# Emiliano
# Elma
# Grace
# Hattie
# Janise
# Jesse
# Jess
# Loss: 1.1620257568359376
# Alan
# Alexander
# Brendon
# Clay
# James
# Jasur
# Janette
# Jay
# Isa
# Isabel
# Freddy
# Frances
# Ivory
# Jayme
# Jana
# Joseph
# Loss: 1.2421748046875
# Andrea
# Ashle
# Ava
# Aryeli
# Antonia
# Carole
# Calvin
# Cisty
# Jedy
# Jeaniella
# Jessie
# Lorissa
# Lance
# Lora
# Lynni
# Ma
# Loss: 1.4208016357421875
# Andia
# Daelee
# Destiney
# Drandra
# Erik
# Karsia
# Kamina
# Keverly
# Kasay
# Kari
# Katherine
# Kailey
# Lenard
# Lynda
# Lew
# Loss: 1.095069091796875
# Amariha
# Elaine
# Esther
# Suzanne
# Christi
# Cameron
# Connie
# Delores
# Cheresa
# Dian
# Edwin
# Elezea
# Emma
# Frances
# K
# Loss: 1.1682667236328126
# Agsila
# Aaris
# Antonio
# Colly
# Dareen
# Latasha
# Linchendall
# Lydia
# Luciano
# Natalie
# Lillie
# Lorenne
# Lucia
# Shar
# Loss: 1.1667991943359375
# Arica
# Aime
# Challe
# Dandra
# Debora
# Earle
# Donnell
# Julio
# Joan
# Jon
# Judiah
# Loren
# Mackenzie
# Martha
# Micaela
# Pr
# Loss: 1.3676265869140625
# Arnk
# Anderson
# Chantel
# Colyn
# Concess
# Davis
# Donnie
# Charles
# Corrine
# Destris
# Dave
# Deron
# Drew
# Drahlie
# Derr
# Loss: 1.123934814453125
# Angela
# Alonza
# Arvan
# Bira
# Carly
# Carl
# Darleen
# Dorothy
# Duane
# Luciano
# Marie
# Melinda
# Maureen
# Many
# Matthew
#
# Loss: 1.0865853271484376
# Abelle
# Alison
# Berty
# Carina
# Carmela
# Camilla
# Chanesta
# Emily
# Hilda
# Jaymin
# Jovanna
# James
# Juanita
# Kasey
# Le
# Loss: 1.2035064697265625
# Alan
# Augustine
# Waddyn
# Alberth
# Alice
# Ann
# Adriann
# Arisannah
# Adele
# Alisa
# Alicia
# Ad
# Aristine
# Bramen
# Bobbi
# Loss: 1.4480008544921874
# Aja
# Auroh
# Catrina
# Crystal
# Elvie
# Ivon
# Rachel
# Cadrick
# Conston
# Darrel
# Debra
# Enrico
# Fred
# Hilda
# Isao
# Jene
#
# Loss: 1.144109130859375
# Andrea
# Alice
# Antonio
# Amie
# Bethany
# Clarence
# Charley
# Carlton
# Deziah
# Edith
# Emani
# Grinah
# Hazel
# Jeremiah
# J
# Loss: 1.8737694091796875
# Anton
# Alvin
# Antonio
# Gwerley
# Hale
# Claudo
# Mike
# Rickey
# Shanter
# Shantel
# Roger
# Titon
# Brie
# Blanche
# Corron
# A
# Loss: 1.1490076904296875
# AChelia
# Antoinette
# Christal
# Christian
# Tammy
# Troy
# Barrey
# Marianne
# Victor
# Aundrey
# Brisa
# Cary
# Cassie
# Che
# Loss: 1.37804345703125
# A
# Bhako
# Carmel
# Sherman
# Chimberto
# Cinthy
# Carson
# Cotte
# Jeremia
# Leichell
# Lou
# Lawrence
# Leslie
# Leigh
# Louia
# Loss: 1.5308594970703124
# Ann
# Arthur
# Rucher
# Bradley
# Jack
# Ricky
# Russett
# Rosetta
# Stella
# Traci
# Johnnie
# Tommie
# Kate
# Robyn
# Samuel
# Su
# Loss: 1.179364501953125
# Andre
# Amber
# Angeline
# Reese
# Alexis
# Andre
# Ariana
# Ashlee
# Alice
# Allian
# Alfonso
# Armand
# Amie
# Alie
# Alexandra
# Loss: 1.4058851318359376
# Aylina
# Cecily
# Jerish
# Lillian
# Meliah
# Marijane
# Rosalinda
# Breant
# Christopher
# Cecilia
# Alox
# Ezendo
# Eli
# Fel
# Loss: 1.1261099853515626
# Antio
# Anisha
# Audrey
# Asher
# Casey
# Christa
# Chanda
# Carrett
# Caroline
# Clay
# Clarenisa
# Dory
# Delma
# Damian
# Dami
# Loss: 1.2183170166015624
# Aidad
# Angel
# Aisha
# Charlene
# Crycia
# Channie
# Dani
# Carolette
# Carlie
# Cristas
# Devon
# Johnnie
# Lorenza
# Lucile
#
# Loss: 1.2133031005859376
# Andres
# Augustin
# Bertha
# Charles
# Canel
# Calmy
# Clinton
# Cody
# ess
# Elma
# Frances
# Izabeth
# Irene
# Harry
# Harrison
# Loss: 1.1231085205078124
# Andrew
# Rashanne
# Tiana
# Yaja
# Arya
# Beatrice
# Carmon
# Cecil
# Carmy
# Anthony
# Ana
# Arelia
# Robbie
# Isaac
# Indaline
#
# Loss: 1.4920186767578125
# Anastael
# Ashlynne
# Aundrea
# Charlene
# Celaria
# Christal
# Dave
# Alexie
# Valiella
# Anna
# Beth
# China
# Corinne
# Corn
# Loss: 1.2623441162109375
# Andra
# Diviem
# Lotty
# Leo
# Lucio
# Otis
# Philip
# Patric
# Rinette
# Roes
# Ree
# Rachel
# Sammy
# Selena
# Sebasa
# Tatian
# Be
# Loss: 1.9242447509765626
# ArAAdrienne
# Ana
# Amana
# Ama
# Ashlee
# Alison
# Wilfred
# Tyrell
# Anthoney
# Bob
# Bryn
# Charlotte
# Chrish
# Marshale
# Ag
# Loss: 1.2467666015625
# Armine
# Ashley
# Patricia
# Estella
# Brianna
# Lela
# Joann
# Julianne
# Kendall
# Leona
# Lynnda
# Liliana
# Loyd
# Malika
# N
# Loss: 1.0951234130859375
# Adriannelle
# Bridgette
# Cassidra
# Cathleen
# Dana
# Edina
# Lillian
# Lucianna
# Susan
# Lucia
# Patricia
# Joanne
# Kara
#
# Loss: 1.065018798828125
# Alo
# Ernest
# Jesus
# Jade
# Jeffrey
# Joanne
# Kent
# Maggie
# Mazel
# Misey
# Ruthal
# Sharon
# Carlos
# Daria
# Dewey
# Delton
#
# Loss: 1.4108560791015625
# Annett
# Angelica
# Anna
# Beverly
# Casandra
# Miley
# Cathie
# Maren
# Cheyanna
# Andre
# Camri
# Christine
# Jaren
# Kathlee
# Loss: 1.3130028076171876
# Aizael
# Aaree
# Ada
# Augustine
# Alexandra
# Alexis
# Annie
# Bertie
# Christine
# Jayne
# Julie
# Edna
# Esther
# Jacory
# Col
# Loss: 1.2182105712890625
# ASA
# Benyan
# Cathy
# Cecilia
# Cory
# Clarence
# Daryl
# Daniel
# Darlene
# David
# Desiree
# Dianne
# Erah
# Ellie
# Edward
# Gr
# Loss: 1.277319091796875
# Acielle
# Arianne
# Amanie
# Bianca
# Blysse
# Brian
# Clara
# Delora
# Felijah
# Garrick
# Louis
# Janinia
# Judith
# Kaitlyn
#
# Loss: 1.517823486328125
# Ayan
# Sally
# Ashey
# Ariel
# Alice
# Ariel
# Andrea
# Becky
# Antoinette
# Carl
# Jessie
# Lacia
# Lilian
# Lawanda
# Maria
# Mar
# Loss: 1.48343505859375
# Adaly
# Amira
# Adeline
# Annabel
# Tamara
# Anne
# Alejandro
# Bulinda
# Cassalyn
# Alaina
# Atzie
# Avabriel
# Alisia
# Allys
# Loss: 1.1942391357421875
# Alexie
# Aaila
# Jaylene
# Iris
# Helen
# Janetta
# Christine
# Cori
# Carissa
# Carissa
# Cheryl
# Christi
# Carolyn
# Carlene
# Loss: 1.3045955810546874
# Allin
# Angelina
# Annika
# Arcina
# Billey
# Brynne
# Demi
# Betty
# Charline
# Cordell
# Charlene
# Erica
# Isabellah
# Lucil
# Loss: 1.2245809326171875
# Alice
# Aileigh
# Carolyn
# Cary
# Christina
# Charlotte
# Chidra
# Danita
# Debra
# Devon
# Destiny
# Evelynn
# Elaine
# Evang
# Loss: 1.22537744140625
# Andre
# Antoe
# Antonio
# Adam
# Dianne
# Earn
# Erthua
# Genevieve
# Jeremi
# Deseana
# Hermon
# Jack
# Keith
# Louis
# Lucas
# Ed
# Loss: 0.9664733276367188
# Andi
# Aleene
# Maxine
# Kaley
# Max
# Sophie
# Ulyssa
# Annie
# Carly
# Catherine
# Carolyn
# Conttany
# Daryl
# Cathy
# Chloe
# C
